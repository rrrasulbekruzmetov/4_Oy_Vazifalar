# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl.metadata (7.3 kB)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.15.3)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (2.2.5)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (3.10.3)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.5.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\rasulbek_ruzmetov\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rasulbek_ruzmetov\appdata\roaming\python\python313\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rasulbek_ruzmetov\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\rasulbek_ruzmetov\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    ---------------------------------------- 1.4/1.4 MB 4.0 MB/s eta 0:00:00
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd

# %%
transactions = [
    ["Milk", "Bread", "Butter"],
    ["Bread", "Eggs"],
    ["Milk", "Bread"],
    ["Bread", "Butter"],
    ["Milk", "Eggs"]
]

# %%
transactions
# Out:
# [['Milk', 'Bread', 'Butter'],
#  ['Bread', 'Eggs'],
#  ['Milk', 'Bread'],
#  ['Bread', 'Butter'],
#  ['Milk', 'Eggs']]

# %%
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
te
# Out:
# TransactionEncoder()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Bread   5 non-null      bool
#  1   Butter  5 non-null      bool
#  2   Eggs    5 non-null      bool
#  3   Milk    5 non-null      bool
# dtypes: bool(4)
# memory usage: 152.0 bytes

# %%
df.head()
# Out:
#    Bread  Butter   Eggs   Milk
# 0   True    True  False   True
# 1   True   False   True  False
# 2   True   False  False   True
# 3   True    True  False  False
# 4  False   False   True   True

# %%
from mlxtend.frequent_patterns import apriori

# %%
frequent_itemsets = apriori(df, min_support=0.3, use_colnames=True)

# %%
frequent_itemsets
# Out:
#    support         itemsets
# 0      0.8          (Bread)
# 1      0.4         (Butter)
# 2      0.4           (Eggs)
# 3      0.6           (Milk)
# 4      0.4  (Bread, Butter)
# 5      0.4    (Bread, Milk)

# %%
from mlxtend.frequent_patterns import association_rules

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

# %%
rules
# Out:
#   antecedents consequents  antecedent support  ...  jaccard  certainty  kulczynski
# 0     (Bread)    (Butter)                 0.8  ...      0.5   0.166667    0.750000
# 1    (Butter)     (Bread)                 0.4  ...      0.5   1.000000    0.750000
# 2     (Bread)      (Milk)                 0.8  ...      0.4  -0.250000    0.583333
# 3      (Milk)     (Bread)                 0.6  ...      0.4  -0.666667    0.583333
#
# [4 rows x 14 columns]

# %%
print("Part 3: Association rules")
print(rules[["antecedents", "consequents", "support", "confidence", "lift"]])
print("\n")
# Out:
# Part 3: Association rules
#   antecedents consequents  support  confidence      lift
# 0     (Bread)    (Butter)      0.4    0.500000  1.250000
# 1    (Butter)     (Bread)      0.4    1.000000  1.250000
# 2     (Bread)      (Milk)      0.4    0.500000  0.833333
# 3      (Milk)     (Bread)      0.4    0.666667  0.833333

# %%
print("Part 4: Evaluation Metrics Explanation")

for index, row in rules.iterrows():
    print(f"Rule: {set(row['antecedents'])} -> {set(row['consequents'])}")
    print(f"Support: {row['support']:.2f}")
    print(f"Confidence: {row['confidence']:.2f}")
    print(f"Lift: {row['lift']:.2f}\n")
# Out:
# Part 4: Evaluation Metrics Explanation
# Rule: {'Bread'} -> {'Butter'}
# Support: 0.40
# Confidence: 0.50
# Lift: 1.25
#
# Rule: {'Butter'} -> {'Bread'}
# Support: 0.40
# Confidence: 1.00
# Lift: 1.25
#
# Rule: {'Bread'} -> {'Milk'}
# Support: 0.40
# Confidence: 0.50
# Lift: 0.83
#
# Rule: {'Milk'} -> {'Bread'}
# Support: 0.40
# Confidence: 0.67
# Lift: 0.83
